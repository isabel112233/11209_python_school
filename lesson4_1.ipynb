# %%
print ("Hello python")
# Out:
# Hello python

# %%
print ("Hello Python")  #str
30     #int
30.0   #float
True   #bool
# Out:
# Hello Python
# True

# %%
# build-in function ->print()

print("Hello Python")
print (30)
print(30.0)
print(True)
# Out:
# Hello Python
# 30
# 30.0
# True

# %%
# int + int ->int
5+2
# Out:
# 7

# %%
#float +float ->float
5.0+2.0
# Out:
# 7.0

# %%
#int + float ->float +float 不同資料類型不能運算，自動將整數轉成浮點數計算
#自動改變型別
5+2.0
# Out:
# 7.0

# %%
#手動改變型別
5 + int(2.0)
# Out:
# 7

# %%
# str + str 

'hello' +' world'
# Out:
# 'hello world'

# %%
# 整數+字串  ->錯誤(不同資料類型)
5 + 'world'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\user\Documents\GitHub\11209_python_school\lesson4_1.ipynb 儲存格 8 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/GitHub/11209_python_school/lesson4_1.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> # 整數+字串
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/GitHub/11209_python_school/lesson4_1.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> 5 + 'world'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#str +str
#手動改變資料類型
str(5) + 'world'
# Out:
# '5world'

# %%
print('501')
int('501')
# Out:
# 501
# 501

# %%
print (5+8)   #5是運算元  +是運算子  8是運算元
print(90-10)  
print(4*7)
print(6/2)     #浮點數除法
print(7 // 2)  #整數除法
print(7 % 3)   #餘數
print(999**20) #次方
# Out:
# 13
# 80
# 28
# 3.0
# 3
# 1
# 980188864829534682605802224588165892518744500843860189980001

# %%
print(5.0+8)
print(5.0+8+10)
print(5.0+8*2)
print(2*(1+2)**2-2**2*2)

# %%
#字串加法運算
"abc" + "efg"
# Out:
# 'abcefg'

# %%
#字串+數值 ->出錯

#"abc" + 13

# %%
# str() ->轉為字串

# %%
2+3*4
# Out:
# 14

# %%
#運算優先順序

# ()
# **
# 正負
# * / % //
# + -
# =

# %%
(2+3)*4
# Out:
# 20

# %%
2 * (1+2)**2-2**2*2
# Out:
# 10

# %%
#建立變數
n1 = 2 + 3 * 4  #=把值放入變數n1,不會傳出值
n1              #傳出n1值
# Out:
# 14

# %%
result = 2 * (1 + 2) ** 2 - 2**2 * 2
result
# Out:
# 10
