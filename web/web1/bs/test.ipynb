# %%
import datasource
import pandas as pd

data:list[tuple] = datasource.lastest_datetime_data()
dataFrame = pd.DataFrame(data)
#for items in dataFrame.to_records():
'''for items in data:
    for item in items:
        print(item)
    print("==============")
'''
dataFrame
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# /workspaces/11209_python_school/web/web1/bs/test.ipynb 儲存格 1 line 4
#       <a href='vscode-notebook-cell://dev-container%..._python_school/web/web1/bs/test.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import datasource
#       <a href='vscode-notebook-cell://dev-container%..._python_school/web/web1/bs/test.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> import pandas as pd
# ----> <a href='vscode-notebook-cell://dev-container%..._python_school/web/web1/bs/test.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> data:list[tuple] = datasource.lastest_datetime_data()
#       <a href='vscode-notebook-cell://dev-container%..._python_school/web/web1/bs/test.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> dataFrame = pd.DataFrame(data)
# ...
